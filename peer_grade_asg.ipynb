# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Fangle Xi
#
# Data Analyst
#
# ***I am interested in data science because I hope to find a job in the USA job market and it seems easier than other job. What's more, I am a statistical student.***

# %% [markdown]
# I hope to learn the answer to the 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# - ABC
# - CDA
#
# ***
#
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
